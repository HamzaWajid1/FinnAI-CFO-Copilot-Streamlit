# %%
import pandas as pd
from agent.tools import convert_to_usd, get_revenue_vs_budget

# Load actuals, budget, fx from CSVs
actuals = pd.read_csv("fixtures/data.csv")
budget = pd.read_csv("fixtures/budget.csv")
fx = pd.read_csv("fixtures/fx.csv")

# Optional: check the first few rows
print(actuals.head())
print(budget.head())
print(fx.head())
# Out:
#      month    entity account_category    amount currency
# 0  2023-01  ParentCo          Revenue  380000.0      USD
# 1  2023-01  ParentCo             COGS   57000.0      USD
# 2  2023-01  ParentCo   Opex:Marketing   76000.0      USD
# 3  2023-01  ParentCo       Opex:Sales   45600.0      USD
# 4  2023-01  ParentCo         Opex:R&D   30400.0      USD
#      month    entity account_category    amount currency
# 0  2023-01  ParentCo          Revenue  400000.0      USD
# 1  2023-01  ParentCo             COGS   56000.0      USD
# 2  2023-01  ParentCo   Opex:Marketing   72000.0      USD
# 3  2023-01  ParentCo       Opex:Sales   44000.0      USD
# 4  2023-01  ParentCo         Opex:R&D   32000.0      USD
#      month currency  rate_to_usd
# 0  2023-01      USD        1.000
# 1  2023-01      EUR        1.085
# 2  2023-02      USD        1.000
# 3  2023-02      EUR        1.092
# 4  2023-03      USD        1.000

# %%
month = "2023-01"
entity = "ParentCo"

text, fig = get_revenue_vs_budget(month, entity, actuals, budget, fx)

# Print text output
print(text)

# Show the chart (if running in Jupyter/IDE)
fig.show()
# Out:
# Revenue in 2023-01 for ParentCo: Actual $380,000 vs Budget $400,000
# C:\Users\hamza\AppData\Local\Temp\ipykernel_23604\3239454691.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import pandas as pd
from tools import convert_to_usd, get_gross_margin_trend1

# Load actuals and FX
actuals = pd.read_csv("../fixtures/data.csv")
fx = pd.read_csv("../fixtures/fx.csv")


entity = "ParentCo"

text, fig = get_gross_margin_trend1(actuals, fx, entity)

# Print text output
print(text)

# Show chart (if running in Jupyter/IDE)
fig.show()
# Out:
# Gross Margin % Trend for ParentCo:
# C:\Users\hamza\AppData\Local\Temp\ipykernel_25692\3910317451.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import sys
import os
__file__=r'C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\agent'
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))

from tools import convert_to_usd, get_opex_breakdown1, get_ebitda_trend, get_ebitda_vs_budget
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 6
#       3 __file__=r'C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\agent'
#       4 sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
# ----> 6 from tools import convert_to_usd, get_opex_breakdown1, get_ebitda_trend, get_ebitda_vs_budget
#
# ImportError: cannot import name 'get_ebitda_trend' from 'tools' (c:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\agent\tools.py)

# %%
print(convert_to_usd)
print(get_opex_breakdown1)
# Out:
# <function convert_to_usd at 0x00000248EE0E2520>
# <function get_opex_breakdown1 at 0x0000024888DB9EE0>

# %%
import os
os.getcwd()  # should show ...\FinnAI coding assignment
# Out:
# 'c:\\Users\\hamza\\OneDrive\\Desktop\\InterviewPrepUSA\\FinnAI coding assignment\\agent'

# %%
import pandas as pd
from tools import convert_to_usd, get_opex_breakdown1

# Load actuals and FX
actuals = pd.read_csv(r"C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\fixtures\data.csv")
fx = pd.read_csv(r"C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\fixtures\fx.csv")


month = "2023-01"
entity = "ParentCo"

text, fig = get_opex_breakdown1(month, entity, actuals, fx)

# Print text summary
print(text)

# Show chart (if running in Jupyter/IDE)
fig.show()
# Out:
# Opex breakdown for 2023-01 (ParentCo):
# Opex:Admin: $22,800
# Opex:Marketing: $76,000
# Opex:R&D: $30,400
# Opex:Sales: $45,600
# C:\Users\hamza\AppData\Local\Temp\ipykernel_25744\2636231448.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import pandas as pd
from tools import get_ebitda_trend, get_ebitda_vs_budget

# Load fixtures
actuals = pd.read_csv(r"C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\fixtures\data.csv")
budget = pd.read_csv(r"C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\fixtures\budget.csv")
fx = pd.read_csv(r"C:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\fixtures\fx.csv")

entity = "ParentCo"
month = "2023-01"

# --- Test EBITDA Trend ---
text_trend, fig_trend = get_ebitda_trend(actuals, fx, entity)
print("[EBITDA Trend]")
print(text_trend)
fig_trend.show()

# --- Test EBITDA vs Budget ---
text_vs, fig_vs = get_ebitda_vs_budget(month, entity, actuals, budget, fx)
print("\n[EBITDA vs Budget]")
print(text_vs)
fig_vs.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hamza\OneDrive\Desktop\InterviewPrepUSA\FinnAI coding assignment\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Opex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
